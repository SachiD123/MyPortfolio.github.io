# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd

# %%
r = requests.get('https://www.imdb.com/list/ls571125270/')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('div', attrs={'class':'lister-item-content'})

# %%
len(results)
# Out:
# 32

# %%
results[0:3]
# Out:
# [<div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt9362722/">Spider-Man: Across the Spider-Verse</a>
#  <span class="lister-item-year text-muted unbold">(2023)</span>
#  </h3>
#  <p class="text-muted text-small">
#  <span class="certificate">PG</span>
#  <span class="ghost">|</span>
#  <span class="runtime">140 min</span>
#  <span class="ghost">|</span>
#  <span class="genre">
#  Animation, Action, Adventure            </span>
#  </p>
#  <div class="ipl-rating-widget">
#  <div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
#  <svg class="ipl-icon ipl-star-icon" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  <path d="M12 17.27L18.18 21l-1.64-7.03L22 9.24l-7.19-.61L12 2 9.19 8.63 2 9.24l5.46 4.73L5.82 21z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
# ...

# %%
def get_name(result):
    try:
        name  = result.find("a").text
    except AttributeError:
        name  = ""
    return name   

def get_year(result):
    try:
        year  = result.find("span",{"class" :"lister-item-year"}).text.strip("()")
    except AttributeError:
        year  = ""
    return year   

def get_genre(result):
    try:
        genre  = result.find("span",{"class" : "genre"}).text.strip()
    except AttributeError:
        genre  = ""
    return genre  

def get_ratings(results):
        rating_span = result.find("span", {"class": "ipl-rating-star__rating"})
        rating = rating_span.text if rating_span is not None else 'N/A'
        return rating

# %%
data =[]
for result in results:
    name  = get_name(result)
    year  = get_year(result)
    genre = get_genre(result)
    ratings = get_ratings(results)
    
    data.append(( name,year, genre, ratings))

print(data)
# Out:
# [('Spider-Man: Across the Spider-Verse', '2023', 'Animation, Action, Adventure', '8.7'), ('Lightyear', '2022', 'Animation, Action, Adventure', '6.1'), ("Guillermo del Toro's Pinocchio", '2022', 'Animation, Drama, Family', '7.6'), ('Turning Red', '2022', 'Animation, Adventure, Comedy', '7'), ('Disenchanted', '2022', 'Animation, Adventure, Comedy', '5.6'), ('Hotel Transylvania: Transformania', '2022', 'Animation, Adventure, Comedy', '6'), ('The Ice Age Adventures of Buck Wild', '2022', 'Animation, Adventure, Comedy', '4.3'), ('DC League of Super-Pets', '2022', 'Animation, Action, Adventure', '7.1'), ("Dragon's Lair: The Movie", '', 'Animation, Action, Adventure', 'N/A'), ('Minions: The Rise of Gru', '2022', 'Animation, Adventure, Comedy', '6.5'), ('The Bad Guys', '2022', 'Animation, Action, Adventure', '6.8'), ("Chip 'n Dale: Rescue Rangers", '2022', 'Animation, Action, Adventure', '7'), ('The Legend of Ochi', '', 'Adventure, Fantasy', 'N/A'), ('Miraculous - Le film', '2023', 'Animatio
# ...

# %%
moviedata = pd.DataFrame(data,columns =['name','year','genre','ratings'])

moviedata.head()
# Out:
#                                   name  year                         genre  \
# 0  Spider-Man: Across the Spider-Verse  2023  Animation, Action, Adventure
# 1                            Lightyear  2022  Animation, Action, Adventure
# 2       Guillermo del Toro's Pinocchio  2022      Animation, Drama, Family
# 3                          Turning Red  2022  Animation, Adventure, Comedy
# 4                         Disenchanted  2022  Animation, Adventure, Comedy
#
#   ratings
# 0     8.7
# 1     6.1
# 2     7.6
# 3       7
# 4     5.6

# %%
#write the data set to csv
moviedata.to_csv("movie.csv",index = False, encoding  = 'utf-8')

# %% [markdown]
# ### data extraction from multiple page

# %%
https://www.imdb.com/search/title/?genres=comedy&explore=title_type,genres&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=3396781f-d87f-4fac-8694-c56ce6f490fe&pf_rd_r=B69G5SRKJMFVS0Z1HB46&pf_rd_s=center-1&pf_rd_t=15051&pf_rd_i=genre&ref_=ft_gnr_pr1_i_1
